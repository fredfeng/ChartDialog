# %%
import pickle
import json
from plotter import *

# %%
ptype = "contour"
pid = 431

# %%
with open("../ChartDialog-data/plots-data/data-series/{}.{}.dataseries.pkl".format(ptype,pid), "rb") as f:
    dt = pickle.load(f)

# %%
with open("../ChartDialog-data/plots-data/params/{}.{}.params.json".format(ptype,pid),"r") as f:
    pp = json.load(f)

# %%
# dt

# %%
# pp

# %%
fig = plotter(**dt, **plotter_kwargs_unnaturalize(**pp))

# %%
pp0 = json.loads("""
{
                        "color_bar_length": "short",
                        "color_bar_orientation": "vertical",
                        "color_bar_thickness": "thin",
                        "color_map": "transparent to solid red",
                        "contour_plot_type": "filled",
                        "font_size": "medium",
                        "grid_line_color": null,
                        "grid_line_style": null,
                        "grid_line_type": null,
                        "grid_line_width": null,
                        "invert_x_axis": false,
                        "invert_y_axis": false,
                        "line_style": null,
                        "line_width": null,
                        "number_of_levels": 6,
                        "plot_type": "contour plot",
                        "polarize": false,
                        "x_axis_position": "bottom",
                        "x_axis_scale": "linear",
                        "y_axis_position": "left",
                        "y_axis_scale": "linear"
                    }
""")

# %%
fig0 = plotter(**dt, **plotter_kwargs_unnaturalize(**pp0))

# %%
pp1 = json.loads("""
{
                        "color_bar_length": "short",
                        "color_bar_orientation": "vertical",
                        "color_bar_thickness": "thin",
                        "color_map": "transparent to solid red",
                        "contour_plot_type": "lined",
                        "font_size": "medium",
                        "grid_line_color": null,
                        "grid_line_style": null,
                        "grid_line_type": null,
                        "grid_line_width": null,
                        "invert_x_axis": false,
                        "invert_y_axis": false,
                        "line_style": "solid",
                        "line_width": "medium",
                        "number_of_levels": 6,
                        "plot_type": "contour plot",
                        "polarize": false,
                        "x_axis_position": "bottom",
                        "x_axis_scale": "linear",
                        "y_axis_position": "left",
                        "y_axis_scale": "linear"
                    }
""")

# %%
fig1 = plotter(**dt, **plotter_kwargs_unnaturalize(**pp1))

# %%
pp2 = json.loads("""
{
                        "arrow_size": "small",
                        "arrow_style": "curve",
                        "color_bar_length": "long",
                        "color_bar_orientation": "horizontal",
                        "color_bar_thickness": "thick",
                        "color_map": "transparent yellow to solid red",
                        "density": "loose",
                        "font_size": "medium",
                        "grid_line_color": "red",
                        "grid_line_style": "dotted",
                        "grid_line_type": "both",
                        "grid_line_width": "very thin",
                        "invert_x_axis": false,
                        "invert_y_axis": true,
                        "line_color": "different",
                        "line_width": "medium",
                        "plot_type": "streamline plot",
                        "x_axis_position": "top",
                        "y_axis_position": "left"
                    }
""")

# %%
fig2 = plotter(**dt, **plotter_kwargs_unnaturalize(**pp2))
